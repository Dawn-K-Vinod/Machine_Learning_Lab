# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load dataset
housing = fetch_california_housing()

data = pd.DataFrame(housing.data,
columns=housing.feature_names)
data["Price"] = housing.target

# %%
# select one feature
X = data[['AveRooms']].values
y = data['Price'].values

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.05,
    random_state = 40
)

# %%
# Feature Scaling
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
w = 0
b = 0

learning_rate = 0.1
epochs = 10000

n = len(X_train_scaled)

for i in range(epochs):
    y_pred = w * X_train_scaled.flatten() + b
    dw = (1/n) * np.sum((y_pred - y_train) * X_train_scaled.flatten())
    db = (1/n) * np.sum(y_pred - y_train)
    w = w - learning_rate * dw
    b = b - learning_rate * db

    if i % 100 == 0:
        cost = (1/(2*n)) * np.sum((y_pred - y_train) ** 2)
        print(f"Epoch {i}, Cost = {cost:.4f}")
y_pred_gd = w * X_test_scaled.flatten() + b
# Out:
# Epoch 0, Cost = 2.7985
# Epoch 100, Cost = 0.6505
# Epoch 200, Cost = 0.6505
# Epoch 300, Cost = 0.6505
# Epoch 400, Cost = 0.6505
# Epoch 500, Cost = 0.6505
# Epoch 600, Cost = 0.6505
# Epoch 700, Cost = 0.6505
# Epoch 800, Cost = 0.6505
# Epoch 900, Cost = 0.6505
# Epoch 1000, Cost = 0.6505
# Epoch 1100, Cost = 0.6505
# Epoch 1200, Cost = 0.6505
# Epoch 1300, Cost = 0.6505
# Epoch 1400, Cost = 0.6505
# Epoch 1500, Cost = 0.6505
# Epoch 1600, Cost = 0.6505
# Epoch 1700, Cost = 0.6505
# Epoch 1800, Cost = 0.6505
# Epoch 1900, Cost = 0.6505
# Epoch 2000, Cost = 0.6505
# Epoch 2100, Cost = 0.6505
# Epoch 2200, Cost = 0.6505
# Epoch 2300, Cost = 0.6505
# Epoch 2400, Cost = 0.6505
# Epoch 2500, Cost = 0.6505
# Epoch 2600, Cost = 0.6505
# Epoch 2700, Cost = 0.6505
# Epoch 2800, Cost = 0.6505
# Epoch 2900, Cost = 0.6505
# Epoch 3000, Cost = 0.6505
# Epoch 3100, Cost = 0.6505
# Epoch 3200, Cost = 0.6505
# Epoch 3300, Cost = 0.6505
# Epoch 3400, Cost = 0.6505
# Epoch 3500, Cost = 0.6505
# Epoch 3600, Cost = 0.6505
# Epoch 3700, Cost = 0.6505
# Epoch 3800, Cost = 0.6505
# Epoch 3900, Cost = 0.6505
# Epoch 4000, Cost = 0.6505
# Epoch 4100, Cost = 0.6505
# Epoch 4200, Cost = 0.6505
# Epoch 4300, Cost = 0.6505
# Epoch 4400, Cost = 0.6505
# Epoch 4500, Cost = 0.6505
# Epoch 4600, Cost = 0.6505
# Epoch 4700, Cost = 0.6505
# Epoch 4800, Cost = 0.6505
# Epoch 4900, Cost = 0.6505
# Epoch 5000, Cost = 0.6505
# Epoch 5100, Cost = 0.6505
# Epoch 5200, Cost = 0.6505
# Epoch 5300, Cost = 0.6505
# Epoch 5400, Cost = 0.6505
# Epoch 5500, Cost = 0.6505
# Epoch 5600, Cost = 0.6505
# Epoch 5700, Cost = 0.6505
# Epoch 5800, Cost = 0.6505
# Epoch 5900, Cost = 0.6505
# Epoch 6000, Cost = 0.6505
# Epoch 6100, Cost = 0.6505
# Epoch 6200, Cost = 0.6505
# Epoch 6300, Cost = 0.6505
# Epoch 6400, Cost = 0.6505
# Epoch 6500, Cost = 0.6505
# Epoch 6600, Cost = 0.6505
# Epoch 6700, Cost = 0.6505
# Epoch 6800, Cost = 0.6505
# Epoch 6900, Cost = 0.6505
# Epoch 7000, Cost = 0.6505
# Epoch 7100, Cost = 0.6505
# Epoch 7200, Cost = 0.6505
# Epoch 7300, Cost = 0.6505
# Epoch 7400, Cost = 0.6505
# Epoch 7500, Cost = 0.6505
# Epoch 7600, Cost = 0.6505
# Epoch 7700, Cost = 0.6505
# Epoch 7800, Cost = 0.6505
# Epoch 7900, Cost = 0.6505
# Epoch 8000, Cost = 0.6505
# Epoch 8100, Cost = 0.6505
# Epoch 8200, Cost = 0.6505
# Epoch 8300, Cost = 0.6505
# Epoch 8400, Cost = 0.6505
# Epoch 8500, Cost = 0.6505
# Epoch 8600, Cost = 0.6505
# Epoch 8700, Cost = 0.6505
# Epoch 8800, Cost = 0.6505
# Epoch 8900, Cost = 0.6505
# Epoch 9000, Cost = 0.6505
# Epoch 9100, Cost = 0.6505
# Epoch 9200, Cost = 0.6505
# Epoch 9300, Cost = 0.6505
# Epoch 9400, Cost = 0.6505
# Epoch 9500, Cost = 0.6505
# Epoch 9600, Cost = 0.6505
# Epoch 9700, Cost = 0.6505
# Epoch 9800, Cost = 0.6505
# Epoch 9900, Cost = 0.6505

# %%
print("Gradient Descent")
print("----------------")
print("Weight: ", w)
print("Bias: ", b)
print("MSE: ", mean_squared_error(y_test, y_pred_gd))
print("R2 Score: ", r2_score(y_test, y_pred_gd))
# Out:
# Gradient Descent
# ----------------
# Weight:  0.17181620869204658
# Bias:  2.0655351948184393
# MSE:  1.2982252905474225
# R2 Score:  0.036962932933771286
